# %%
import MySQLdb
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
# connecting to the database
# engine = create_engine('mysql+mysqldb://{}:{}@localhost/{}'.format('root','', 'employee'), pool_pre_ping=True)

# conn = MySQLdb._mysql.connect(host='localhost',port=3306,user='root', passwd='',db='employee',charset='utf8')
# cur = conn.cursor()
# help(MySQLdb)

# %%
Base = declarative_base()

# %%
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 Base.metadata.create_all(engine)
#
# NameError: name 'engine' is not defined

# %%
dir(MySQLdb._mysql)
# Out:
# ['DataError',
#  'DatabaseError',
#  'Error',
#  'IntegrityError',
#  'InterfaceError',
#  'InternalError',
#  'MySQLError',
#  'NotSupportedError',
#  'OperationalError',
#  'ProgrammingError',
#  'Warning',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  'connect',
#  'connection',
#  'debug',
#  'escape',
#  'escape_string',
#  'get_client_info',
#  'result',
#  'string_literal',
#  'version_info']

# %%
# Connecting with MySQLdb
instant = {    
    'host' : 'localhost',
    'port' : 3306,
    'user' : 'root', 
    'passwd' : '',
    'db' : 'employee',
#     'charset' : 'utf8'
}
conn = MySQLdb._mysql.connect(**instant)
cur = conn.cursor()
cur.execute("SELECT * FROM states ORDER BY id ASC")
query_rows = cur.fetchall()
for row in query_rows():
    print(row)
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [9], in <cell line: 10>()
#       1 # Connecting with MySQLdb
#       2 instant = {
#       3     'host' : 'localhost',
#       4     'port' : 3306,
#    (...)
#       8 #     'charset' : 'utf8'
#       9 }
# ---> 10 conn = MySQLdb._mysql.connect(**instant)
#      11 cur = conn.cursor()
#      12 cur.execute("SELECT * FROM states ORDER BY id ASC")
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' (10061)")

# %%
# Connecting with sqlalchemy
Session = sessionmaker()
engine = create_engine('mysql+mysqldb://{}:{}@localhost/{}'.format('root','', 'employee'), pool_pre_ping=True)
Base.metadata.create_all(engine)
Session.configure(bind=engine)
session = Session(engine)
for state in session.query(state).order_by(State.id).all():
    print("{}: {}".formar(state.id, state.name))
session.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\users\hp\appdata\local\programs\python\python39-32\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File c:\users\hp\appdata\local\programs\python\python39-32\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File c:\users\hp\appdata\local\programs\python\python39-32\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
# ...
